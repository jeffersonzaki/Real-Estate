# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from functions import *

# %%
# Choosing certain columns that will be used
house_df = pd.read_csv("Data/kc_house_data.csv")[["price", "bathrooms", "floors", "waterfront"]]

house_df.dropna(inplace=True)  # Dropping missing values

# %% [markdown]
# ## Creating subset dataframe for waterfront and price

# %%
house_df.head()
# Out:
#        price  bathrooms  floors  waterfront
# 1   538000.0       2.25     2.0         0.0
# 2   180000.0       1.00     1.0         0.0
# 3   604000.0       3.00     1.0         0.0
# 4   510000.0       2.00     1.0         0.0
# 5  1230000.0       4.50     1.0         0.0

# %%
# Creating separate dataframes with houses with or without waterfronts
waterfront1 = house_df.loc[house_df.waterfront == 1.0]
waterfront0 = house_df.loc[house_df.waterfront == 0.0]

# %% [markdown]
# ## Creating subset dataframe for floors and price

# %%
# Creating a separate dataframe that shows floors of the properties
floor1 = house_df.loc[house_df.floors == 1]
floor2 = house_df.loc[house_df.floors == 2]

# %% [markdown]
# ## Creating subset dataframe for bathrooms and price

# %%
# Creating a dataframe that shows rows that shows the number of desired bathrooms
bathrooms_more_than_2 = house_df.loc[house_df.bathrooms > 2]
bathrooms_less_and_2 = house_df.loc[house_df.bathrooms <= 2]

# %% [markdown]
# # Visualization of Data

# %%
ax = sns.boxplot(x="waterfront", y="price",
                 data=house_df, palette="Set3")
#The diamonds indicate outliers

# %%
ax = sns.boxplot(x="floors", y="price",
                 data=house_df, palette="Set3")
#The diamonds indicate outliers

# %%
# Figure size
plt.figure(figsize=(10, 9))

# Variables
x = np.array([0, 1])
y = np.array([waterfront0_std, waterfront1_std])

# Distribution Graph
sns.barplot(x, y)

# Labels
plt.title("Waterfront property price", fontsize=20)
plt.xlabel("Waterfronts(yes:1, no:0)", fontsize=15)
plt.ylabel("Standard Deviation", fontsize=15)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# Figure size
plt.figure(figsize=(10, 9))

# Box Plot
sns.violinplot(floor1.price)

# Labels
plt.title("Price of a 1 floor house")
plt.show()

# %%
# Figure size
plt.figure(figsize=(10, 9))

# Box Plot
sns.violinplot(floor2.price)

# Labels
plt.title("Price of a 2 floor house")
plt.show()
